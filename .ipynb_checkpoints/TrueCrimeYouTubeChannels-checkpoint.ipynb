# %% [markdown]
# # Set things up to get data from YouTube

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
# from IPython.display import JSON

# %%
api_key = 'AIzaSyAKo96zShqgmZ4Mz7Vk2rSKC2YrEd3k3Bw'

# %% [markdown]
# This csv is one that I made by looking in the source code for each of the channels I wanted to analyze.  These are my favorite YouTube true crime channels.

# %%
id_df = pd.read_csv('data/YouTubeChannelids.csv')
id_df
# Out:
#                         channel_name                channel_id
# 0                      Bailey Sarian  UCtNdVINwfYFTQEEZgMiQ8FA
# 1          JCS - Criminal Psychology  UCYwVxWpjeKFWwu8TML-Te9A
# 2                    Danielle Kirsty  UC7QBeubzVIOqFjUjd_gNEBQ
# 3   Matt Orchard - Crime and Society  UCYUZ0gWRp_HQCVEz0OovuAg
# 4     Buzzfeed Unsolved - True Crime  UCKijjvu6bN1c-ZHVwR7-5WA
# 5                       That Chapter  UCL44k-cLrlsdr7PYuMU4yIw
# 6                  Stephanie Harlowe  UClVF8RcTN3UqAognWFGlJcg
# 7                   this is MONSTERS  UC43NNGKNN6I3KqT963L6o6Q
# 8                  Coffeehouse Crime  UCcUf33cEPky2GiWBgOP-jQA
# 9             The Casual Criminalist  UCp1tsmksyf6TgKFMdt8-05Q
# 10                       Kendall Rae  UCKBaL17hXLGJvi2KZKpja5w
# 11                   Explore with Us  UCJWKjrrUh2KL1d3zXQW79cQ
# 12                      Joshua Miles  UCu6hgG6SUHhAa2clb66hRhw
# 13                       Bella Fiori  UCaezsZGhwWgB4ZRmHNCfIyw
# 14   dreading (crime and psychology)  UCG-qQe1mnh4JVKhuJkdh8KA
# 15          Annie Elise x 10 to LIFE  UCOK0fZAUx82plnLhTKZW6qg
# 16                        Dr. Grande  UCC_0vyFTKk1Nlodo4QsiQkw
# 17                     Eleanor Neale  UCFMbX7frWZfuWdjAML0babA
# 18                          48 Hours  UC7htuVs06oduI3xSfTdcxPA
# 19                        Crime Reel  UC8uw4lQjJnNZBxJu8_ATV5w
# 20              Little Shop of Crime  UCs9sNzoR8ReeqPC8EB-HjXg

# %%
channel_ids = list(id_df['channel_id'])
channel_ids
# Out:
# ['UCtNdVINwfYFTQEEZgMiQ8FA',
#  'UCYwVxWpjeKFWwu8TML-Te9A',
#  'UC7QBeubzVIOqFjUjd_gNEBQ',
#  'UCYUZ0gWRp_HQCVEz0OovuAg',
#  'UCKijjvu6bN1c-ZHVwR7-5WA',
#  'UCL44k-cLrlsdr7PYuMU4yIw',
#  'UClVF8RcTN3UqAognWFGlJcg',
#  'UC43NNGKNN6I3KqT963L6o6Q',
#  'UCcUf33cEPky2GiWBgOP-jQA',
#  'UCp1tsmksyf6TgKFMdt8-05Q',
#  'UCKBaL17hXLGJvi2KZKpja5w',
#  'UCJWKjrrUh2KL1d3zXQW79cQ',
#  'UCu6hgG6SUHhAa2clb66hRhw',
#  'UCaezsZGhwWgB4ZRmHNCfIyw',
#  'UCG-qQe1mnh4JVKhuJkdh8KA',
#  'UCOK0fZAUx82plnLhTKZW6qg',
#  'UCC_0vyFTKk1Nlodo4QsiQkw',
#  'UCFMbX7frWZfuWdjAML0babA',
#  'UC7htuVs06oduI3xSfTdcxPA',
#  'UC8uw4lQjJnNZBxJu8_ATV5w',
#  'UCs9sNzoR8ReeqPC8EB-HjXg']

# %% [markdown]
# ## Use the YouTube API to gather channel data

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
                
        all_data.append(data)
                
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#                         Channel_name Subscribers       Views Total_videos  \
# 0                        Kendall Rae     3530000   602684970          685
# 1                    Dr. Todd Grande     1290000   320540626         2836
# 2   Matt Orchard - Crime and Society      210000    12711124           27
# 3           Annie Elise x 10 to LIFE      737000    95497164          443
# 4          BuzzFeed Unsolved Network     5380000  1923346108          674
# 5                  Coffeehouse Crime     1680000   226322239          164
# 6                      Eleanor Neale     2530000   424746234          239
# 7             The Casual Criminalist      448000    63171006          242
# 8                       Joshua Miles      187000    18128228          171
# 9                           48 Hours      772000   212733118         1373
# 10                      That Chapter     1850000   710658606          490
# 11                   Danielle Kirsty      805000   123828611          238
# 12                    The Crime Reel       99100    11666687          213
# 13          The Little Shop of Crime       46200     2010018           24
# 14                 Stephanie Harlowe      813000   154120828          496
# 15                   EXPLORE WITH US     3840000   743888976          431
# 16         JCS - Criminal Psychology     5400000   387629066           20
# 17                       Bella Fiori     2580000   277639184          443
# 18                  this is MONSTERS      643000   130444671          301
# 19   dreading (crime and psychology)      531000    58919851           86
# 20                     Bailey Sarian     6900000   982067417          524
#
#                  playlist_id
# 0   UUKBaL17hXLGJvi2KZKpja5w
# 1   UUC_0vyFTKk1Nlodo4QsiQkw
# 2   UUYUZ0gWRp_HQCVEz0OovuAg
# 3   UUOK0fZAUx82plnLhTKZW6qg
# 4   UUKijjvu6bN1c-ZHVwR7-5WA
# 5   UUcUf33cEPky2GiWBgOP-jQA
# 6   UUFMbX7frWZfuWdjAML0babA
# 7   UUp1tsmksyf6TgKFMdt8-05Q
# 8   UUu6hgG6SUHhAa2clb66hRhw
# 9   UU7htuVs06oduI3xSfTdcxPA
# 10  UUL44k-cLrlsdr7PYuMU4yIw
# 11  UU7QBeubzVIOqFjUjd_gNEBQ
# 12  UU8uw4lQjJnNZBxJu8_ATV5w
# 13  UUs9sNzoR8ReeqPC8EB-HjXg
# 14  UUlVF8RcTN3UqAognWFGlJcg
# 15  UUJWKjrrUh2KL1d3zXQW79cQ
# 16  UUYwVxWpjeKFWwu8TML-Te9A
# 17  UUaezsZGhwWgB4ZRmHNCfIyw
# 18  UU43NNGKNN6I3KqT963L6o6Q
# 19  UUG-qQe1mnh4JVKhuJkdh8KA
# 20  UUtNdVINwfYFTQEEZgMiQ8FA

# %% [markdown]
# ### All column types are object, so change numeric types

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Channel_name  21 non-null     object
#  1   Subscribers   21 non-null     int64
#  2   Views         21 non-null     int64
#  3   Total_videos  21 non-null     int64
#  4   playlist_id   21 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 968.0+ bytes

# %% [markdown]
# ### Sort dataframe from highest number of subscribers to lowest

# %%
channel_data.sort_values('Subscribers', ascending=False, inplace=True, ignore_index=True)
channel_data
# Out:
#                         Channel_name  Subscribers       Views  Total_videos  \
# 0                      Bailey Sarian      6900000   982067417           524
# 1          JCS - Criminal Psychology      5400000   387629066            20
# 2          BuzzFeed Unsolved Network      5380000  1923346108           674
# 3                    EXPLORE WITH US      3840000   743888976           431
# 4                        Kendall Rae      3530000   602684970           685
# 5                        Bella Fiori      2580000   277639184           443
# 6                      Eleanor Neale      2530000   424746234           239
# 7                       That Chapter      1850000   710658606           490
# 8                  Coffeehouse Crime      1680000   226322239           164
# 9                    Dr. Todd Grande      1290000   320540626          2836
# 10                 Stephanie Harlowe       813000   154120828           496
# 11                   Danielle Kirsty       805000   123828611           238
# 12                          48 Hours       772000   212733118          1373
# 13          Annie Elise x 10 to LIFE       737000    95497164           443
# 14                  this is MONSTERS       643000   130444671           301
# 15   dreading (crime and psychology)       531000    58919851            86
# 16            The Casual Criminalist       448000    63171006           242
# 17  Matt Orchard - Crime and Society       210000    12711124            27
# 18                      Joshua Miles       187000    18128228           171
# 19                    The Crime Reel        99100    11666687           213
# 20          The Little Shop of Crime        46200     2010018            24
#
#                  playlist_id
# 0   UUtNdVINwfYFTQEEZgMiQ8FA
# 1   UUYwVxWpjeKFWwu8TML-Te9A
# 2   UUKijjvu6bN1c-ZHVwR7-5WA
# 3   UUJWKjrrUh2KL1d3zXQW79cQ
# 4   UUKBaL17hXLGJvi2KZKpja5w
# 5   UUaezsZGhwWgB4ZRmHNCfIyw
# 6   UUFMbX7frWZfuWdjAML0babA
# 7   UUL44k-cLrlsdr7PYuMU4yIw
# 8   UUcUf33cEPky2GiWBgOP-jQA
# 9   UUC_0vyFTKk1Nlodo4QsiQkw
# 10  UUlVF8RcTN3UqAognWFGlJcg
# 11  UU7QBeubzVIOqFjUjd_gNEBQ
# 12  UU7htuVs06oduI3xSfTdcxPA
# 13  UUOK0fZAUx82plnLhTKZW6qg
# 14  UU43NNGKNN6I3KqT963L6o6Q
# 15  UUG-qQe1mnh4JVKhuJkdh8KA
# 16  UUp1tsmksyf6TgKFMdt8-05Q
# 17  UUYUZ0gWRp_HQCVEz0OovuAg
# 18  UUu6hgG6SUHhAa2clb66hRhw
# 19  UU8uw4lQjJnNZBxJu8_ATV5w
# 20  UUs9sNzoR8ReeqPC8EB-HjXg

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(channel_data, x='Subscribers', y='Channel_name')

# %%
ax = sns.barplot(channel_data, y='Channel_name', x='Views')

# %% [markdown]
# I'm starting to think that BuzzFeed Unsolved Network has way more than just the true crime, in which case I'm going to delete it from this analysis.

# %%
ax = sns.barplot(channel_data, y='Channel_name', x='Total_videos')

# %% [markdown]
# Hmmm. Maybe not.

# %% [markdown]
# Now, the last column in this new dataframe is playlist_id.  This is the id for the "playlist" of *all* videos uploaded by that YouTuber.  From each playlist_id, we can get information about all of the videos, like title, views, likes, description, and more.

# %%
# function to fetch all video id's from the upload playlist id
def get_video_ids_limit(youtube, playlist_id):
    video_ids = []
    for id in channel_data['playlist_id']:
        request = youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50)
        response = request.execute()
    
    for r in response['items']:
        vid_id = r['contentDetails']['videoId']
        video_ids.append(vid_id)
    
    return video_ids

# %%
bailey_playlist = channel_data[channel_data['Channel_name']=="Bailey Sarian"]['playlist_id'][0]
bailey_ids = get_video_ids_limit(youtube, bailey_playlist)

# %%
len(bailey_ids)
# Out:
# 50

# %% [markdown]
# Next, I'm going to write a new function so I remember the simplicity of the old one.  (Also because the last time I extended this to use nextPageToken it fell apart. 😵‍💫)

# %% [markdown]
# ## Function to get ALL video ids from a channel

# %%
# Write the function to get ALL video id's even though there is a limit of 50 at a time through the API
def get_video_ids(youtube, playlist_id):
    video_ids = []
    for id in channel_data['playlist_id']:
        request = youtube.playlistItems().list(
                    part = 'contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50)
        response = request.execute()
    
    for r in response['items']:
        vid_id = r['contentDetails']['videoId']
        video_ids.append(vid_id)
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            for id in channel_data['playlist_id']:
                request = youtube.playlistItems().list(
                            part = 'contentDetails',
                            playlistId = playlist_id,
                            maxResults = 50,
                            pageToken = next_page_token)
                response = request.execute()
            for r in response['items']:
                vid_id = r['contentDetails']['videoId']
                video_ids.append(vid_id)
            next_page_token = response.get('nextPageToken')
            
    
    return video_ids

# %%
len(bailey_vid_ids)
# Out:
# 524

# %% [markdown]
# This worked well, so let's clean up and find relevant info from one YouTuber at a time, then we can put them all back together again later.

# %% [markdown]
# # Create a dataframe for each YouTuber

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    
    all_video_stats = []
    
    for i in range(0,len(video_ids),50):
        request = youtube.videos().list(
                    part='snippet, statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
            
        for r in response['items']:
            try:
                video_stats = dict(Title = r['snippet']['title'],
                                   PublishedDate = r['snippet']['publishedAt'],
                                   Views = r['statistics']['viewCount'],
                                   Likes = r['statistics']['likeCount'],
                                   Comments = r['statistics']['commentCount'],
                                   )
            except:
                try: 
                    video_stats = dict(Title = r['snippet']['title'],
                                       PublishedDate = r['snippet']['publishedAt'],
                                       # Views = r['statistics']['viewCount'],
                                       Likes = r['statistics']['likeCount'],
                                       Comments = r['statistics']['commentCount'],
                                       )
                except:
                    try: 
                        video_stats = dict(Title = r['snippet']['title'],
                                           PublishedDate = r['snippet']['publishedAt'],
                                           Views = r['statistics']['viewCount'],
                                           Likes = r['statistics']['likeCount'],
                                           # Comments = r['statistics']['commentCount'],
                                           )
                    except:
                        video_stats = dict(Title = r['snippet']['title'],
                                           PublishedDate = r['snippet']['publishedAt'],
                                           Views = r['statistics']['viewCount'],
                                           # Likes = r['statistics']['likeCount'],
                                           Comments = r['statistics']['commentCount'],
                                          )
                
            all_video_stats.append(video_stats)
            
    return all_video_stats

# %% [markdown]
# Let's try this on just one channel first.

# %%
bailey_stats = get_video_details(youtube, bailey_vid_ids)
len(bailey_stats)
# Out:
# 524

# %%
bailey_df = pd.DataFrame(bailey_stats)
bailey_df
# Out:
#                                                  Title         PublishedDate  \
# 0    A Killer Deadlier than Hitler? Joseph Stalin P...  2023-05-18T19:00:06Z
# 1    His Waterbed Secrets - Life Sentence At 14?! J...  2023-05-15T19:00:18Z
# 2    The Mass Murderer Nobody Talks About: Joseph S...  2023-05-11T19:00:04Z
# 3    The Woodworking Wacko - Psychopath Cameron Hoo...  2023-05-08T19:00:16Z
# 4    This Bloody Crime Saved Our Lives: The Dark Hi...  2023-05-04T19:00:13Z
# ..                                                 ...                   ...
# 519                                 WHATS IN MY BAG ?!  2015-07-22T00:49:02Z
# 520           DRAMATIC LINER // SMOKEY MAKEUP TUTORIAL  2015-07-21T06:05:02Z
# 521                 DRUGSTORE HAUL // FIRST IMPRESSION  2015-06-28T17:00:01Z
# 522             RED LIP // SIMPLE GOLD SHADOW TUTORIAL  2015-06-10T08:23:06Z
# 523                  My foundation, contour, highlight  2013-09-12T19:36:43Z
#
#        Views  Likes Comments
# 0     259964  12594     1262
# 1    1495774  61599     4896
# 2     663264  24257     2470
# 3    2095206  72485     4535
# 4     688278  25916     1498
# ..       ...    ...      ...
# 519    70608   2531      164
# 520    36310   2580       99
# 521    89248   4030      228
# 522    74473   3984      165
# 523   382849  22676     3368
#
# [524 rows x 5 columns]

# %%
bailey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          524 non-null    object
#  1   PublishedDate  524 non-null    object
#  2   Views          523 non-null    object
#  3   Likes          524 non-null    object
#  4   Comments       524 non-null    object
# dtypes: object(5)
# memory usage: 20.6+ KB

# %%
bailey_df['PublishedDate'] = pd.to_datetime(bailey_df['PublishedDate'], utc=True)
bailey_df['Views'] = pd.to_numeric(bailey_df['Views'])
bailey_df['Likes'] = pd.to_numeric(bailey_df['Likes'])
bailey_df['Comments'] = pd.to_numeric(bailey_df['Comments'])
bailey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          524 non-null    object
#  1   PublishedDate  524 non-null    datetime64[ns, UTC]
#  2   Views          523 non-null    float64
#  3   Likes          524 non-null    int64
#  4   Comments       524 non-null    int64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(1)
# memory usage: 20.6+ KB

# %%
bailey_df.drop('Favorites', axis=1, inplace=True)
bailey_df.head()
# Out:
#                                                Title  \
# 0  A Killer Deadlier than Hitler? Joseph Stalin P...
# 1  His Waterbed Secrets - Life Sentence At 14?! J...
# 2  The Mass Murderer Nobody Talks About: Joseph S...
# 3  The Woodworking Wacko - Psychopath Cameron Hoo...
# 4  This Bloody Crime Saved Our Lives: The Dark Hi...
#
#               PublishedDate      Views  Likes  Comments
# 0 2023-05-18 19:00:06+00:00   253125.0  12379      1246
# 1 2023-05-15 19:00:18+00:00  1476546.0  61188      4821
# 2 2023-05-11 19:00:04+00:00   656700.0  24147      2470
# 3 2023-05-08 19:00:16+00:00  2084745.0  72309      4524
# 4 2023-05-04 19:00:13+00:00   687067.0  25895      1497

# %%
bailey_df['PublishedDate'] = bailey_df['PublishedDate'].dt.date
bailey_df.head()
# Out:
#                                                Title PublishedDate      Views  \
# 0  A Killer Deadlier than Hitler? Joseph Stalin P...    2023-05-18   259964.0
# 1  His Waterbed Secrets - Life Sentence At 14?! J...    2023-05-15  1495774.0
# 2  The Mass Murderer Nobody Talks About: Joseph S...    2023-05-11   663264.0
# 3  The Woodworking Wacko - Psychopath Cameron Hoo...    2023-05-08  2095206.0
# 4  This Bloody Crime Saved Our Lives: The Dark Hi...    2023-05-04   688278.0
#
#    Likes  Comments
# 0  12594      1262
# 1  61599      4896
# 2  24257      2470
# 3  72485      4535
# 4  25916      1498

# %%
bailey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          524 non-null    object
#  1   PublishedDate  524 non-null    object
#  2   Views          523 non-null    float64
#  3   Likes          524 non-null    int64
#  4   Comments       524 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 20.6+ KB

# %%
top_ten = bailey_df.sort_values(['Views'], ascending=False).head(10)

# %%
top_ten
# Out:
#                                                  Title PublishedDate  \
# 195  Jeffrey Dahmer. Inside His Messed Up Mind & Ho...    2020-02-17
# 116  Devil In Disguise As A Killer Clown - John Way...    2021-10-18
# 154  1 Of The Most Hated Women In America Casey Ant...    2021-02-01
# 175  Cam Girl Obsession Turns Deadly [ Amato Case ]...    2020-06-22
# 203  The Night Stalker : Richard Ramirez | Mystery ...    2020-01-13
# 292  Chris Watts - 2000 Page Discovery Murder, Myst...    2019-01-15
# 111  *CAUGHT* Four Decades Later - Untold Story Of ...    2021-11-08
# 125  Missouri's Mysterious Disappearance -  VANISHE...    2021-08-30
# 240  The Creeper White Van & Tool Box - This Couldv...    2019-08-12
# 153  Love, Lies & Lust - What Really Happened With ...    2021-02-08
#
#           Views   Likes  Comments
# 195  25823771.0  359901     19687
# 116  15222324.0  198092      9768
# 154  14650519.0  468809     41671
# 175  14063378.0  332155     16836
# 203  11144183.0  241479     11250
# 292  11057169.0  246122     10445
# 111  10971793.0  202853     10240
# 125  10931851.0  224890     17752
# 240  10821375.0  173998      8492
# 153  10578586.0  283221     17873

# %%
ax1 = sns.barplot(x="Views", y='Title', data=top_ten)

# %%
bailey_df['Month'] = pd.to_datetime(bailey_df['PublishedDate']).dt.strftime('%b')
bailey_df.head()
# Out:
#                                                Title PublishedDate      Views  \
# 0  A Killer Deadlier than Hitler? Joseph Stalin P...    2023-05-18   253125.0
# 1  His Waterbed Secrets - Life Sentence At 14?! J...    2023-05-15  1476546.0
# 2  The Mass Murderer Nobody Talks About: Joseph S...    2023-05-11   656700.0
# 3  The Woodworking Wacko - Psychopath Cameron Hoo...    2023-05-08  2084745.0
# 4  This Bloody Crime Saved Our Lives: The Dark Hi...    2023-05-04   687067.0
#
#    Likes  Comments Month
# 0  12379      1246   May
# 1  61188      4821   May
# 2  24147      2470   May
# 3  72309      4524   May
# 4  25895      1497   May

# %%
bailey_by_month = bailey_df.groupby('Month', as_index=False).size()
bailey_by_month
# Out:
#    Month  size
# 0    Apr    43
# 1    Aug    43
# 2    Dec    47
# 3    Feb    49
# 4    Jan    46
# 5    Jul    38
# 6    Jun    33
# 7    Mar    47
# 8    May    44
# 9    Nov    42
# 10   Oct    46
# 11   Sep    46

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
bailey_by_month.index = pd.CategoricalIndex(bailey_by_month['Month'], categories=sort_order, ordered=True)
bailey_by_month
# Out:
#       Month  size
# Month
# Apr     Apr    43
# Aug     Aug    43
# Dec     Dec    47
# Feb     Feb    49
# Jan     Jan    46
# Jul     Jul    38
# Jun     Jun    33
# Mar     Mar    47
# May     May    44
# Nov     Nov    42
# Oct     Oct    46
# Sep     Sep    46

# %%
bailey_by_month.drop('Month', axis=1, inplace=True)
bailey_by_month
# Out:
#        size
# Month
# Apr      43
# Aug      43
# Dec      47
# Feb      49
# Jan      46
# Jul      38
# Jun      33
# Mar      47
# May      44
# Nov      42
# Oct      46
# Sep      46

# %%
bailey_by_month = bailey_by_month.sort_index()
bailey_by_month
# Out:
#        size
# Month
# Jan      46
# Feb      49
# Mar      47
# Apr      43
# May      44
# Jun      33
# Jul      38
# Aug      43
# Sep      46
# Oct      46
# Nov      42
# Dec      47

# %%
ax2 = sns.barplot(x=bailey_by_month.index, y='size', data=bailey_by_month)

# %% [markdown]
# ## Make the rest of the dataframes (one for each of the other 20 channels)

# %%
# first, come up with short, descriptive names for each dataframe
# we will remake the bailey sarian we did above for consistency
names = ['bailey','jcs','buzzfeed','explore','kendall','bella','eleanor','chapter','coffee','grande','harlowe',
         'kirsty','forty8','annie','monsters','dreading','casual','orchard','miles','reel','shop']
# names = [bailey, jcs, buzzfeed, explore]
len(names)
# Out:
# 21

# %% [markdown]
# ### Make a list of all video ids for each channel

# %%
vid_ids_dict = {}
i = 0

for name in names:
    print(f"Getting playlist ids for {name}")
    playlist_id = channel_data.iloc[i]['playlist_id']
    ids = get_video_ids(youtube, playlist_id)
    vid_ids_dict[name] = ids
    i += 1
    
len(vid_ids_dict)
# Out:
# Getting playlist ids for bailey
# Getting playlist ids for jcs
# Getting playlist ids for buzzfeed
# Getting playlist ids for explore
# Getting playlist ids for kendall
# Getting playlist ids for bella
# Getting playlist ids for eleanor
# Getting playlist ids for chapter
# Getting playlist ids for coffee
# Getting playlist ids for grande
# Getting playlist ids for harlowe
# Getting playlist ids for kirsty
# Getting playlist ids for forty8
# Getting playlist ids for annie
# Getting playlist ids for monsters
# Getting playlist ids for dreading
# Getting playlist ids for casual
# Getting playlist ids for orchard
# Getting playlist ids for miles
# Getting playlist ids for reel
# Getting playlist ids for shop
# 21

# %% [markdown]
# Check the lengths of a few of the playlists

# %%
len(vid_ids_dict["kendall"])
# Out:
# 685

# %%
len(vid_ids_dict['shop'])
# Out:
# 24

# %%
vid_ids_dict['jcs']
# Out:
# ['Hy6XsXseDfM',
#  '4iluOmq1DYY',
#  'CGuEdN-ju2g',
#  'Mwt35SEeR9w',
#  'N274EurzpAA',
#  'BemHqUqcpI8',
#  'UQt46gvYO40',
#  'eJt_afGN3IQ',
#  '9x2NaGkl6BI',
#  'HkRjIq8Cp2A',
#  'j3PLLOreTLY',
#  'sVF_SlzxBJ4',
#  'L0H6xYwMQnk',
#  '7JttwV6XZ_I',
#  '1J2YOLQM2Yc',
#  'sv0iN5J-9mk',
#  'WLSNPkf8RCU',
#  'jJZv3z7FOt0',
#  'nVZhV7M3mNE',
#  'Xfg861hO-Ag']

# %% [markdown]
# ## Create a dataframe for each channel using its video ids

# %%
# names = ['jcs', 'orchard']
# it worked great with just two!! :)
# now let's do them all

for name in names:
    print(f"Building dataframe {name}...")
    stats = get_video_details(youtube, vid_ids_dict[name])
    vars()[name] = pd.DataFrame(stats)
# Out:
# Building dataframe bailey...
# Building dataframe jcs...
# Building dataframe buzzfeed...
# Building dataframe explore...
# Building dataframe kendall...
# Building dataframe bella...
# Building dataframe eleanor...
# Building dataframe chapter...
# Building dataframe coffee...
# Building dataframe grande...
# Building dataframe harlowe...
# Building dataframe kirsty...
# Building dataframe forty8...
# Building dataframe annie...
# Building dataframe monsters...
# Building dataframe dreading...
# Building dataframe casual...
# Building dataframe orchard...
# Building dataframe miles...
# Building dataframe reel...
# Building dataframe shop...

# %% [markdown]
# Check out the first 2 rows of each dataframe

# %%
for name in names:
    print(f"\n\n======================================================================================\n{name}:")
    display(vars()[name].head(2))
# Out:
# ======================================================================================
# bailey:
#                                                Title         PublishedDate  \
# 0  A Killer Deadlier than Hitler? Joseph Stalin P...  2023-05-18T19:00:06Z
# 1  His Waterbed Secrets - Life Sentence At 14?! J...  2023-05-15T19:00:18Z
#
#      Views  Likes Comments
# 0   259346  12567     1262
# 1  1493531  61537     4885
# ======================================================================================
# jcs:
#                                                Title         PublishedDate  \
# 0   Sarah literally thinks she's going home later...  2023-03-24T23:36:10Z
# 1  Son Spends $275,000 of Dad’s Money on Virtual ...  2023-02-15T18:46:28Z
#
#       Views   Likes Comments
# 0  13685203  293135    57337
# 1   7627554  220711    46645
# ======================================================================================
# buzzfeed:
#                                                Title         PublishedDate  \
# 0  The Most Notorious Serial Killer From Iowa #sh...  2023-05-19T18:00:12Z
# 1  An Undertaker Answer Questions About Death #sh...  2023-05-18T18:00:14Z
#
#    Views Likes Comments
# 0  10567   372       13
# 1  10873   441       26
# ======================================================================================
# explore:
#                                              Title         PublishedDate  \
# 0   When An Evil Mother Realizes She's Been Caught  2023-05-14T22:48:51Z
# 1  Predator Realizes He's Going To Prison For Life  2023-05-07T17:42:45Z
#
#      Views  Likes Comments
# 0  2371669  64135    13371
# 1  3056912  61099     6414
# ======================================================================================
# kendall:
#                                                Title         PublishedDate  \
# 0  Lies Exposed Around the Death of Shanquella Ro...  2023-05-19T18:00:21Z
# 1                Woman Burns Deceased Husband's Will  2023-05-17T14:00:41Z
#
#    Views Likes Comments
# 0  22536  1739       46
# 1  14715   761       15
# ======================================================================================
# bella:
#                                  Title         PublishedDate   Views  Likes  \
# 0  CASSIE STODDART: THE SCREAM KILLERS  2023-05-15T17:01:35Z  217019   8473
# 1          SOLVED | THE DISCORD KILLER  2023-05-08T17:01:56Z  288349  11654
#
#   Comments
# 0      332
# 1      462
# ======================================================================================
# eleanor:
#                                    Title         PublishedDate    Views  \
# 0  He Hid 'Murder Kits' All Over America  2023-05-04T18:30:12Z   794527
# 1      The Twisted Mind Of Casey Anthony  2023-04-19T21:18:00Z  1413804
#
#    Likes Comments
# 0  27154     1598
# 1  46524     4335
# ======================================================================================
# chapter:
#                                   Title         PublishedDate   Views  Likes  \
# 0  The Cruel Affair of Micaela Costanzo  2023-05-16T19:00:31Z  623227  36569
# 1  The Sinister Plot of Sheila Davalloo  2023-05-12T19:00:22Z  664466  36207
#
#   Comments
# 0     5116
# 1     2549
# ======================================================================================
# coffee:
#                                                Title         PublishedDate  \
# 0  He Turned his victims into "BBQ Pork"... | The...  2023-05-18T15:00:40Z
# 1  She lured men in to murder them... | The Case ...  2023-05-15T15:00:25Z
#
#     Views  Likes Comments
# 0  390928  21744     1463
# 1  497334  27864     2883
# ======================================================================================
# grande:
#                                                Title         PublishedDate  \
# 0  Family Survives After Tesla Travels Off Cliff ...  2023-05-20T21:08:55Z
# 1  Narcissism and Daily Conversation Word Selecti...  2023-05-20T04:36:19Z
#
#   Views Likes Comments
# 0  8176  1224      206
# 1  8303   921       95
# ======================================================================================
# harlowe:
#                                                Title         PublishedDate  \
# 0      Coffee and Crime Time: Noel Rodriguez Alvarez  2023-05-18T22:09:52Z
# 1  The Mystery Of The Missing Fort Worth Trio: Pa...  2023-05-13T18:31:22Z
#
#     Views Likes Comments
# 0  141092  9677     1332
# 1  172702  9881      878
# ======================================================================================
# kirsty:
#                                                Title         PublishedDate  \
# 0  The MASTER Manipulator Who Conned Women, Faked...  2023-05-14T21:11:59Z
# 1  12 Days of Captivity Because She Turned Down a...  2023-05-07T16:00:01Z
#
#     Views  Likes Comments
# 0  418320  17627     1131
# 1  381917  19481     1101
# ======================================================================================
# forty8:
#                                                Title         PublishedDate  \
# 0  New Jersey woman survives stabbing during home...  2023-05-20T23:00:03Z
# 1  Woman's love for her daughter helped her survi...  2023-05-19T18:47:16Z
#
#    Views Likes Comments
# 0   2330   199        0
# 1  20583   655       38
# ======================================================================================
# annie:
#                            Title         PublishedDate  Views Likes Comments
# 0      The Case of Kouri Richins  2023-05-20T17:30:01Z   4372   540        0
# 1  Wife Tries to Poison Husband?  2023-05-19T18:45:00Z  11632  1149       33
# ======================================================================================
# monsters:
#                                                Title         PublishedDate  \
# 0  Larry & Carri Williams : The Guide to Child Abuse  2023-05-18T07:00:21Z
# 1    Julie Schenecker : The Murder of Calyx and Beau  2023-05-15T07:00:15Z
#
#     Views  Likes Comments
# 0  131309   9236     2067
# 1  178816  10744     1725
# ======================================================================================
# dreading:
#                                  Title         PublishedDate   Views  Likes  \
# 0  When your roommate kills his family  2023-05-17T15:00:01Z  238241  11834
# 1    When your son kills your daughter  2023-05-10T16:38:00Z  282986  14106
#
#   Comments
# 0     1662
# 1     1895
# ======================================================================================
# casual:
#                                Title         PublishedDate  Views Likes  \
# 0  The Lonely Hearts Killers #shorts  2023-05-20T15:00:40Z   5508   609
# 1            Colonel Russel Williams  2023-05-19T19:00:27Z  70925  4687
#
#   Comments
# 0        0
# 1      859
# ======================================================================================
# orchard:
#                                                Title         PublishedDate  \
# 0         The Unspeakable Murder of Savanna Greywind  2023-05-11T19:00:05Z
# 1  This is What a Lazy-Bones Looks Like | Cart Na...  2023-04-01T19:00:31Z
#
#     Views  Likes Comments
# 0  150670   7452     1331
# 1  118448  10297     2881
# ======================================================================================
# miles:
#                                                Title         PublishedDate  \
# 0  Inside the Investigation: How a SUITCASE solve...  2023-02-28T22:18:37Z
# 1  The Police Ignored Their Calls For Help - The ...  2023-02-19T21:00:19Z
#
#    Views Likes Comments
# 0  35394  2158       98
# 1  65157  2698      170
# ======================================================================================
# reel:
#                                            Title         PublishedDate  Views  \
# 0           When a Peacock wants to help out ...  2023-05-13T20:00:02Z   1784
# 1  The Haunting Deaths of Don Henry & Kevin Ives  2023-05-10T11:00:05Z  13298
#
#   Likes Comments
# 0   395       89
# 1  1605      346
# ======================================================================================
# shop:
#                                                Title         PublishedDate  \
# 0                  The Sickening Case of Zara Aleena  2023-05-06T15:33:04Z
# 1  This 1km Trail of Blood Led to a Brutal Crime ...  2023-03-27T19:44:23Z
#
#     Views Likes Comments
# 0   17737  1382      175
# 1  193254  5406      447

# %% [markdown]
# ### Fix data types

# %%
jcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          20 non-null     object
#  1   PublishedDate  20 non-null     object
#  2   Views          20 non-null     object
#  3   Likes          20 non-null     object
#  4   Comments       20 non-null     object
# dtypes: object(5)
# memory usage: 928.0+ bytes

# %%
vars()[names[0]].PublishedDate = pd.
# Out:
# 0      2023-05-18T19:00:06Z
# 1      2023-05-15T19:00:18Z
# 2      2023-05-11T19:00:04Z
# 3      2023-05-08T19:00:16Z
# 4      2023-05-04T19:00:13Z
#                ...
# 519    2015-07-22T00:49:02Z
# 520    2015-07-21T06:05:02Z
# 521    2015-06-28T17:00:01Z
# 522    2015-06-10T08:23:06Z
# 523    2013-09-12T19:36:43Z
# Name: PublishedDate, Length: 524, dtype: object

# %%
# we'll do the easy columns first:)
for name in names:
    vars()[name]['Views'] = pd.to_numeric(vars()[name]['Views'])
    vars()[name]['Likes'] = pd.to_numeric(vars()[name]['Likes'])
    vars()[name]['Comments'] = pd.to_numeric(vars()[name]['Comments'])
jcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          20 non-null     object
#  1   PublishedDate  20 non-null     object
#  2   Views          20 non-null     int64
#  3   Likes          20 non-null     int64
#  4   Comments       20 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 928.0+ bytes

# %%
for name in names:
    vars()[name]['PublishedDate'] = pd.to_datetime(vars()[name]['PublishedDate'], utc=True)

# %%
jcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          20 non-null     object
#  1   PublishedDate  20 non-null     datetime64[ns, UTC]
#  2   Views          20 non-null     int64
#  3   Likes          20 non-null     int64
#  4   Comments       20 non-null     int64
# dtypes: datetime64[ns, UTC](1), int64(3), object(1)
# memory usage: 928.0+ bytes

# %%
for name in names:
    vars()[name]['PublishedDate'] = vars()[name]['PublishedDate'].dt.date

# %%
jcs.head()
# Out:
#                                                Title PublishedDate     Views  \
# 0   Sarah literally thinks she's going home later...    2023-03-24  13685203
# 1  Son Spends $275,000 of Dad’s Money on Virtual ...    2023-02-15   7627554
# 2                            Yeardley's Ex-Boyfriend    2022-12-21   6132902
# 3             What pretending to be crazy looks like    2021-05-26  64682862
# 4                                      Wrath of Jodi    2020-12-24  34530508
#
#      Likes  Comments
# 0   293135     57337
# 1   220711     46645
# 2   310296     77714
# 3  1752245    198055
# 4   584290    137857

# %%
for name in names:
    vars()[name]['Month'] = pd.to_datetime(vars()[name]['PublishedDate']).dt.strftime('%b')

# %%
jcs.head()
# Out:
#                                                Title PublishedDate     Views  \
# 0   Sarah literally thinks she's going home later...    2023-03-24  13685203
# 1  Son Spends $275,000 of Dad’s Money on Virtual ...    2023-02-15   7627554
# 2                            Yeardley's Ex-Boyfriend    2022-12-21   6132902
# 3             What pretending to be crazy looks like    2021-05-26  64682862
# 4                                      Wrath of Jodi    2020-12-24  34530508
#
#      Likes  Comments Month
# 0   293135     57337   Mar
# 1   220711     46645   Feb
# 2   310296     77714   Dec
# 3  1752245    198055   May
# 4   584290    137857   Dec
